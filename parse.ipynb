# %%
import pandas as pd

# %%
from parse_timeline import parse_tl_csv

gdp_df = parse_tl_csv("datasets/gdp_datasets/gdp_timeline.csv")
cpi_df = parse_tl_csv("datasets/cpi_datasets/cpi_timeline.csv")
agri_df = parse_tl_csv("datasets/agriculture_datsets/agri_timeline.csv")
agri_p_df = parse_tl_csv("datasets/agri_percent_dataset/agri_p_timeline.csv")

# %%
gdp_df.head()
# Out:
#                    Country Name Country Code     Indicator Name  \
# 1   Africa Eastern and Southern          AFE  GDP (current US$)
# 3    Africa Western and Central          AFW  GDP (current US$)
# 13                    Australia          AUS  GDP (current US$)
# 14                      Austria          AUT  GDP (current US$)
# 16                      Burundi          BDI  GDP (current US$)
#
#     Indicator Code  Year         Value
# 1   NY.GDP.MKTP.CD  1960  2.421063e+10
# 3   NY.GDP.MKTP.CD  1960  1.190495e+10
# 13  NY.GDP.MKTP.CD  1960  1.860768e+10
# 14  NY.GDP.MKTP.CD  1960  6.624086e+09
# 16  NY.GDP.MKTP.CD  1960  1.960000e+08

# %%
cpi_df.head()
# Out:
#     Country Name Country Code                     Indicator Name  \
# 13     Australia          AUS  Consumer price index (2010 = 100)
# 14       Austria          AUT  Consumer price index (2010 = 100)
# 17       Belgium          BEL  Consumer price index (2010 = 100)
# 19  Burkina Faso          BFA  Consumer price index (2010 = 100)
# 28       Bolivia          BOL  Consumer price index (2010 = 100)
#
#    Indicator Code  Year      Value
# 13    FP.CPI.TOTL  1960   7.960458
# 14    FP.CPI.TOTL  1960  17.824167
# 17    FP.CPI.TOTL  1960  15.596081
# 19    FP.CPI.TOTL  1960  10.713301
# 28    FP.CPI.TOTL  1960   0.000022

# %%
agri_df.head()
# Out:
#     Country Name Country Code  \
# 286   Bangladesh          BGD
# 294      Bolivia          BOL
# 295       Brazil          BRA
# 299     Botswana          BWA
# 305        Chile          CHL
#
#                                         Indicator Name     Indicator Code  \
# 286  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 294  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 295  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 299  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 305  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
#
#      Year     Value
# 286  1961  5.208137
# 294  1961  4.889299
# 295  1961  7.600000
# 299  1961  2.463062
# 305  1961 -1.836386

# %%
agri_p_df.head()
# Out:
#     Country Name Country Code  \
# 18         Benin          BEN
# 19  Burkina Faso          BFA
# 20    Bangladesh          BGD
# 29        Brazil          BRA
# 33      Botswana          BWA
#
#                                        Indicator Name  Indicator Code  Year  \
# 18  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS  1960
# 19  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS  1960
# 20  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS  1960
# 29  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS  1960
# 33  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS  1960
#
#         Value
# 18  46.157723
# 19  38.484533
# 20  57.474312
# 29   0.000000
# 33  43.222960

# %%
print("GDP shape:", gdp_df.shape)
print("CPI shape:", cpi_df.shape)
print("Agri Growth shape:", agri_df.shape)
print("Agri % of GDP shape:", agri_p_df.shape)
# Out:
# GDP shape: (14307, 6)
# CPI shape: (8904, 6)
# Agri Growth shape: (10022, 6)
# Agri % of GDP shape: (10921, 6)

# %%
location_df = pd.read_csv("datasets/agriculture_datsets/income_groups.csv")

location_df = location_df.rename(columns={
    "TableName": "Name",
    "Country Code": "Country",
    "Region": "Region"
})

location_df = location_df[
    (location_df["Country"].str.len() == 3) &
    (location_df["Region"].notnull()) &
    (location_df["Region"] != "")
]

location_df = location_df[["Name", "Country", "Region"]]
location_df.head()
# Out:
#           Name Country                     Region
# 0        Aruba     ABW  Latin America & Caribbean
# 2  Afghanistan     AFG                 South Asia
# 4       Angola     AGO         Sub-Saharan Africa
# 5      Albania     ALB      Europe & Central Asia
# 6      Andorra     AND      Europe & Central Asia
