# %%
import pandas as pd

# %%
ag_growth = pd.read_csv("datasets/micro_datasets/agri_timeline.csv")
industry_growth = pd.read_csv("datasets/micro_datasets/industry_timeline.csv")
manu_growth = pd.read_csv("datasets/micro_datasets/manufacturing_timeline.csv")
service_growth = pd.read_csv("datasets/micro_datasets/service_timeline.csv")

# %%
ag_growth
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 1    Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 2    Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 3    Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 4    Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# ..                                                 ...                ...
# 261  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 262  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 263  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 264  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
# 265  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KD.ZG
#
#      1960      1961      1962      1963      1964      1965  ...       2015  \
# 0     NaN       NaN       NaN       NaN       NaN       NaN  ...        NaN
# 1     NaN       NaN       NaN       NaN       NaN       NaN  ...   3.414389
# 2     NaN       NaN       NaN       NaN       NaN       NaN  ...  -5.657218
# 3     NaN       NaN       NaN       NaN       NaN       NaN  ...   3.504946
# 4     NaN       NaN       NaN       NaN       NaN       NaN  ...  10.160481
# ..    ...       ...       ...       ...       ...       ...  ...        ...
# 261   NaN       NaN       NaN       NaN       NaN       NaN  ...  17.924762
# 262   NaN       NaN       NaN       NaN       NaN       NaN  ... -17.691194
# 263   NaN  3.713848  5.671529  3.239914 -11.45212  1.109773  ...  -3.637629
# 264   NaN       NaN       NaN       NaN       NaN       NaN  ...  -7.736634
# 265   NaN       NaN       NaN       NaN       NaN       NaN  ...  -5.256535
#
#           2016       2017       2018       2019       2020       2021  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1     2.312357   3.994806   2.151072   1.713093   3.780958   4.134563
# 2     5.971752   6.411059  -4.415311  17.459825   5.942340  -9.780634
# 3     4.244629   4.918266   3.248648   2.343420   2.612906   3.136455
# 4     3.852721   0.457775  -2.482599  -1.747257   2.843708  17.204850
# ..         ...        ...        ...        ...        ...        ...
# 261  15.966571  -3.980439 -10.448860  12.409123  -5.761472  -2.491332
# 262  12.534294   2.003686   7.419462        NaN        NaN        NaN
# 263  -5.151363  19.080359   0.492936  -6.521409  17.259515   5.566310
# 264   3.719521   9.788283 -21.177497   7.702659  17.206766   6.934456
# 265  -3.895121  10.035361  18.406940 -10.402825   4.149892  17.475076
#
#           2022       2023  Unnamed: 68
# 0          NaN        NaN          NaN
# 1     2.961900   1.231300          NaN
# 2    -6.564078   2.060824          NaN
# 3     3.379935   1.725906          NaN
# 4     3.939829   2.712516          NaN
# ..         ...        ...          ...
# 261   4.516932  -2.966124          NaN
# 262        NaN        NaN          NaN
# 263   2.038402  -4.782619          NaN
# 264 -10.617078 -20.451846          NaN
# 265   6.152919   6.313705          NaN
#
# [266 rows x 69 columns]
